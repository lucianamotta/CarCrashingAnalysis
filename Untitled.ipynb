# %%
def map_contributing_factors(column):
#Separating columns "CONTRIBUTING FACTOR VEHICLE" in groups and creating new columns with this groups. 
# OBS.: In the first moment, my idea was to group Contributing Factor in less categories to create dummies a posteriori.
#During the implementation I realized that the dataset will be large, so I decided to group to after encoding the columns.

    maping = {
        'Accelerator Defective': 'Defects in the vehicle',
        'Aggressive Driving/Road Rage': 'Inadequate driving behavior',
        'Alcohol Involvement': 'Use of alcohol or licit/illicit drugs',
        'Animals Action': 'Animals on the road',
        'Backing Unsafely': 'Inadequate driving behavior',
        'Brakes Defective': 'Defects in the vehicle',
        'Cell Phone (hand-Held)': 'Use of electronic devices',
        'Cell Phone (hand-held)': 'Use of electronic devices',
        'Cell Phone (hands-free)': 'Use of electronic devices',
        'Driver Inattention/Distraction': 'Inadequate driving behavior',
        'Driver Inexperience': 'Inadequate driving behavior',
        'Driverless/Runaway Vehicle': 'Inadequate driving behavior',
        'Drugs (illegal)': 'Use of alcohol or licit/illicit drugs',
        'Drugs (Illegal)': 'Use of alcohol or licit/illicit drugs',
        'Eating or Drinking': 'Inadequate driving behavior',
        'Failure to Keep Right': 'Inadequate driving behavior',
        'Failure to Yield Right-of-Way': 'Inadequate driving behavior',
        'Fatigued/Drowsy': 'Driver Physical conditions',
        'Fell Asleep':  'Driver Physical conditions',
        'Following Too Closely': 'Inadequate driving behavior',
        'Glare': 'Others',
        'Headlights Defective': 'Defects in the vehicle',
        'Illnes':'Driver Physical conditions',
        'Lane Marking Improper/Inadequate':'Inappropriate Road conditions', 
        'Listening/Using Headphones': 'Use of electronic devices',
        'Lost Consciousness' : 'Driver Physical conditions',
        'Obstruction/Debris' : 'Inappropriate Road conditions',
        'Other Electronic Device' : 'Use of electronic devices',
        'Other Lighting Defects': 'Inappropriate Road conditions',
        'Other Vehicular': 'Misbehavior by another driver',
        'Outside Car Distraction': 'Inadequate driving behavior',
        'Oversized Vehicle': 'Others',
        'Passenger Distraction': 'Inadequate driving behavior',
        'Passing or Lane Usage Improper':'Inadequate driving behavior',
        'Passing Too Closely': 'Inadequate driving behavior',
        'Pavement Defective': 'Inappropriate Road conditions',
        'Pavement Slippery': 'Inappropriate Road conditions',
        'Pedestrian/Bicyclist/Other Pedestrian Error/Confusion':'Pedestrian or Bicyclist bad behavior',
        'Physical Disability':'Driver Physical conditions',
        'Prescription Medication': 'Use of alcohol or licit/illicit drugs',
        'Reaction to Other Uninvolved Vehicle': 'Misbehavior by another driver',
        'Reaction to Uninvolved Vehicle': 'Misbehavior by another driver',
        'Shoulders Defective/Improper': 'Defects in the vehicle',
        'Steering Failure': 'Defects in the vehicle',
        'Texting': 'Use of electronic devices',
        'Tinted Windows': 'Defects in the vehicle',
        'Tire Failure/Inadequate': 'Defects in the vehicle',
        'Tow Hitch Defective': 'Defects in the vehicle',
        'Traffic Control Device Improper/Non-Working': 'Signaling failure',
        'Traffic Control Disregarded': 'Inadequate driving behavior',
        'Turning Improperly': 'Inadequate driving behavior',
        'Unsafe Lane Changing': 'Inadequate driving behavior',
        'Unsafe Speed': 'Inadequate driving behavior',    
        'Using On Board Navigation Device':'Use of electronic devices',
        'Vehicle Vandalism':'Others',
        'View Obstructed/Limited': 'Inappropriate Road conditions',
        'Windshield Inadequate':'Defects in the vehicle'    

    }

    return maping
